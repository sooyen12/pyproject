# %% [markdown]
# <a href="https://colab.research.google.com/github/sooyen12/pyproject/blob/main/%EC%86%A1%ED%8C%8C%EA%B5%AC(CCTV_%26_bicycle).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import folium
# 엑셀 파일 경로 지정
file_path = '/content/drive/MyDrive/학교 수업/2025년 1학기 /2025 1학기 - 파이썬 데이터 분석/팀 프로젝트/CCTV정보(송파구).xlsx'

# 엑셀 파일 읽기
df_cctv = pd.read_excel(file_path)

# 첫 번째 몇 줄 확인
df_cctv.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    번호       관리기관명              소재지도로명주소              소재지지번주소 설치목적구분  카메라대수  \
# 0   1  서울특별시 송파구청  서울특별시 송파구 동남로23다길 10  서울특별시 송파구 오금동 52-10   생활방범      1
# 1   2  서울특별시 송파구청   서울특별시 송파구 성내천로6길 13  서울특별시 송파구 오금동 70-18   생활방범      1
# 2   3  서울특별시 송파구청   서울특별시 송파구 성내천로6길 13  서울특별시 송파구 오금동 70-18   생활방범      1
# 3   4  서울특별시 송파구청   서울특별시 송파구 성내천로6길 13  서울특별시 송파구 오금동 70-18   생활방범      1
# 4   5  서울특별시 송파구청   서울특별시 송파구 동남로26길 18  서울특별시 송파구 오금동 154-3   생활방범      1
#
#    카메라화소수    촬영방면정보  보관일수  설치연월      관리기관전화번호    WGS84위도     WGS84경도  \
# 0     200  360도 전방면    30   NaN  02-2147-2410  37.503826  127.133003
# 1     200  360도 전방면    30   NaN  02-2147-2410  37.504158  127.134903
# 2     200  360도 전방면    30   NaN  02-2147-2410  37.504158  127.134903
# ...

# %%
import pandas as pd
import folium
# CSV 파일 경로 (코랩에 직접 업로드한 경우 경로를 맞춰줘야 함)
file_path = '/content/drive/MyDrive/학교 수업/2025년 1학기 /2025 1학기 - 파이썬 데이터 분석/팀 프로젝트/12_23_bicycle.csv'  # 이 경로는 너가 직접 업로드한 위치에 따라 달라질 수 있음

# CSV 파일 불러오기
df_bicycle = pd.read_csv(file_path,encoding='cp949')

# %%
# 위도, 경도 컬럼 이름
latitude_column = 'WGS84위도'
longitude_column = 'WGS84경도'

# 방면 컬럼 정리 (공백 제거, 문자열 처리)
df_cctv['촬영방면정보'] = df_cctv['촬영방면정보'].astype(str).str.strip()

# 지도 중심을 첫 번째 좌표로 설정
center_lat = df_cctv[latitude_column].iloc[0]
center_lon = df_cctv[longitude_column].iloc[0]

# %%
# 공백 제거 후 문자열에 '서울특별시 송파구'가 포함된 행만 필터링
df_bicycle['시도시군구명'] = df_bicycle['시도시군구명'].astype(str).str.strip()
songpa_df = df_bicycle[df_bicycle['시도시군구명'].str.contains('서울특별시 송파구', na=False)]

# %%
# 자전거 사고 다발지역 좌표 컬럼명
latitude = '위도'
longitude = '경도'

# %%
# 지도 생성 (송파구 중심)
map_center = [37.5145, 127.1065]
m = folium.Map(location=map_center, zoom_start=13)

# 지도에 원 그리기
for _, row in songpa_df.iterrows():
    lat = row[latitude]
    lon = row[longitude]
    folium.Circle(
        location=[lat, lon],
        radius=10,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.4,
    ).add_to(m)

# 원 그리기
for _, row in df_cctv.iterrows():
    lat = row[latitude_column]
    lon = row[longitude_column]
    direction = row['촬영방면정보']

    # 360도 전방 여부에 따라 색상 지정
    if '360' in direction:
        color = 'red'
    else:
        color = 'gray'

    folium.Circle(
        location=[lat, lon],
        radius=10,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.3,
        popup=direction
    ).add_to(m)


# 지도 출력
m
